# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('housepriice.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.isnull().sum().sort_values(ascending= False).head(19)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
df['SalePrice'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# group 1 Nan value group

# %%
group1 = df[['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu',
            'GarageQual', 'GarageFinish', 'GarageType', 'GarageCond','BsmtFinType2',
            'BsmtExposure','BsmtCond', 'BsmtQual', 'BsmtFinType1' ]]

# %%
df[group1.columns] = df[group1.columns].fillna('None')

# %% [markdown]
# group 2 numaric columns

# %%
group2 = df[['LotFrontage', 'GarageYrBlt', 'MasVnrArea']]

# %%
df[group2.columns]= df[group2.columns].fillna(df[group2.columns].median())

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %%
df.isnull().sum().sort_values(ascending= False).head(19)
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# Alley           0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# dtype: int64

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.histplot(data = df, x = 'SalePrice', kde = True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
df['SalePrice'].skew()
# Out:
# np.float64(1.8828757597682129)

# %% [markdown]
# EDA

# %%
for clm in group2:
    plt.figure(figsize= (6,4))
    sns.scatterplot(data = df , x = clm, y = 'SalePrice')
    plt.xlabel(f"{clm}")
    plt.ylabel("SalePrice")
    plt.title(f"Relation of {clm} vs Saleprice")

# %%
df.corr(numeric_only=True)["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# Fireplaces       0.466929
# GarageYrBlt      0.466754
# BsmtFinSF1       0.386420
# LotFrontage      0.334771
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
sns.boxplot(data = df, x = 'OverallQual', y = 'SalePrice')
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.scatterplot(data = df, x = 'GrLivArea', y= 'SalePrice')
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# Feature Engineering

# %%
df['Totalsf'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']

# %%
df['TotalBathrooms'] = df['FullBath'] + df['BsmtFullBath'] + (0.5*df['HalfBath']) + (0.5*df['BsmtHalfBath'])

# %%
df['HouseAge'] = df['YrSold'] - df['YearBuilt']

# %%
df['Remodage'] = df['YrSold'] - df['YearRemodAdd']

# %%
df['TotalPorchSF'] = df['OpenPorchSF'] + df['3SsnPorch'] + df['EnclosedPorch'] + df['ScreenPorch']

# %%
df['TotalPorchSF'].head()
# Out:
# 0     61
# 1      0
# 2     42
# 3    307
# 4     84
# Name: TotalPorchSF, dtype: int64

# %% [markdown]
# Categorical Encoding

# %%
df.select_dtypes(include= 'object').columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_cols = [
    'ExterQual', 'ExterCond',
    'BsmtQual', 'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1', 'BsmtFinType2',
    'HeatingQC', 'KitchenQual',
    'FireplaceQu',
    'GarageFinish',
    'GarageQual', 'GarageCond',
    'PoolQC'
]

encoder = OrdinalEncoder(
    handle_unknown='use_encoded_value',
    unknown_value=-1
)

df[ordinal_cols] = encoder.fit_transform(df[ordinal_cols])

# %%
df[ordinal_cols].head()
# Out:
#    ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# 0        2.0        4.0       2.0       4.0           3.0           2.0
# 1        3.0        4.0       2.0       4.0           1.0           0.0
# 2        2.0        4.0       2.0       4.0           2.0           2.0
# 3        3.0        4.0       4.0       1.0           3.0           0.0
# 4        2.0        4.0       2.0       4.0           0.0           2.0
#
#    BsmtFinType2  HeatingQC  KitchenQual  FireplaceQu  GarageFinish  \
# 0           6.0        0.0          2.0          3.0           2.0
# 1           6.0        0.0          3.0          5.0           2.0
# 2           6.0        0.0          2.0          5.0           2.0
# 3           6.0        2.0          2.0          2.0           3.0
# 4           6.0        0.0          2.0          5.0           2.0
#
#    GarageQual  GarageCond  PoolQC
# 0         5.0         5.0     3.0
# 1         5.0         5.0     3.0
# ...

# %%
nominal_cols = [
    'MSZoning',
    'Street',
    'Alley',
    'LotShape',
    'LandContour',
    'Utilities',
    'LotConfig',
    'LandSlope',
    'Neighborhood',
    'Condition1',
    'Condition2',
    'BldgType',
    'HouseStyle',
    'RoofStyle',
    'RoofMatl',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Foundation',
    'Heating',
    'CentralAir',
    'Electrical',
    'SaleType',
    'SaleCondition'
]

# %%
df = pd.get_dummies(df, columns=nominal_cols, drop_first=True)

# %%
df = pd.get_dummies(df, columns=['Functional', 'PavedDrive', 'Fence'], drop_first=True)

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Id              0
# MSSubClass      0
# LotFrontage     0
# LotArea         0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# MasVnrArea      0
# ExterQual       0
# dtype: int64

# %%
df = pd.get_dummies(df, columns=['GarageType', 'MiscFeature'], drop_first=True)

# %%
df.shape
# Out:
# (1460, 221)

# %% [markdown]
# ML Part

# %%
X = df.drop(['SalePrice'], axis = 1)
y = df['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    random_state= 42,
    test_size= 0.2
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model_linear = LinearRegression()
model_linear.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred_linear = model_linear.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred_linear)
mae
# Out:
# 21685.174432135147

# %%
r2 = r2_score(y_test, y_pred_linear)
r2
# Out:
# 0.674051313196627

# %%
rmse = root_mean_squared_error(y_test, y_pred_linear)
rmse
# Out:
# 50001.32752823809

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
model_ridge = Ridge(alpha= 1.0)
model_ridge.fit(X_train_scaled,y_train)
# Out:
# Ridge()

# %%
y_pred_ridge = model_ridge.predict(X_test_scaled)

# %%
metrics = {
    'rmse' : root_mean_squared_error(y_test, y_pred_ridge),
    'mae' : mean_absolute_error(y_test, y_pred_ridge),
    'r2' : r2_score(y_test, y_pred_ridge)
}
metrics
# Out:
# {'rmse': 47719.099428360605,
#  'mae': 21441.073449477284,
#  'r2': 0.7031270393532805}

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
model_lasso = Lasso(alpha = 1.0)
model_lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso()

# %%
y_pred_lasso = model_lasso.predict(X_test_scaled)

# %%
metrics = {
    'rmse' : root_mean_squared_error(y_test, y_pred_lasso),
    'mae' : mean_absolute_error(y_test, y_pred_lasso),
    'r2' : r2_score(y_test, y_pred_lasso)
}
metrics
# Out:
# {'rmse': 49973.994399158284,
#  'mae': 21649.801357803535,
#  'r2': 0.6744075742349745}

# %% [markdown]
# DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_DT = DecisionTreeRegressor(random_state= 42)
model_DT.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred_DT = model_DT.predict(X_test)

# %%
metrics = {
    'rmse' : root_mean_squared_error(y_test, y_pred_DT),
    'mae' : mean_absolute_error(y_test, y_pred_DT),
    'r2' : r2_score(y_test, y_pred_DT)
}
metrics
# Out:
# {'rmse': 42155.3003883114, 'mae': 26550.69178082192, 'r2': 0.7683189341851399}

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_random_forest = RandomForestRegressor(
    n_estimators=100,
    criterion='squared_error', max_depth=None,
    random_state= 42
)

# %%
model_random_forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_random_forest = model_random_forest.predict(X_test)

# %%
metrics = {
    'rmse' : root_mean_squared_error(y_test, y_pred_random_forest),
    'mae' : mean_absolute_error(y_test, y_pred_random_forest),
    'r2' : r2_score(y_test, y_pred_random_forest)
}
metrics
# Out:
# {'rmse': 29761.359295657705,
#  'mae': 17935.313424657532,
#  'r2': 0.8845240106874085}

# %%
importance = model_random_forest.feature_importances_

feature_importance = pd.Series(
    importance,
    index=X_train.columns
).sort_values(ascending=False)

feature_importance.head(15)
# Out:
# OverallQual       0.385979
# Totalsf           0.365778
# 2ndFlrSF          0.027995
# YearBuilt         0.014929
# LotArea           0.013009
# TotalBathrooms    0.010526
# BsmtFinSF1        0.010441
# HouseAge          0.010248
# LotFrontage       0.010053
# GarageCars        0.009901
# GrLivArea         0.009646
# BsmtQual          0.008562
# GarageArea        0.008001
# KitchenQual       0.007627
# YearRemodAdd      0.006909
# dtype: float64
