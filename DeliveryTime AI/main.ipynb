# %% [markdown]
# DeliveryTime AI

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Food_Delivery_Times.csv')

# %%
df.head()
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   int64
#  1   Distance_km             1000 non-null   float64
#  2   Weather                 970 non-null    str
#  3   Traffic_Level           970 non-null    str
#  4   Time_of_Day             970 non-null    str
#  5   Vehicle_Type            1000 non-null   str
#  6   Preparation_Time_min    1000 non-null   int64
#  7   Courier_Experience_yrs  970 non-null    float64
#  8   Delivery_Time_min       1000 non-null   int64
# dtypes: float64(2), int64(3), str(4)
# memory usage: 91.3 KB

# %%
df.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  1000.000000  1000.000000           1000.000000              970.000000
# mean    500.500000    10.059970             16.982000                4.579381
# std     288.819436     5.696656              7.204553                2.914394
# min       1.000000     0.590000              5.000000                0.000000
# 25%     250.750000     5.105000             11.000000                2.000000
# 50%     500.500000    10.190000             17.000000                5.000000
# 75%     750.250000    15.017500             23.000000                7.000000
# max    1000.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count        1000.000000
# mean           56.732000
# std            22.070915
# min             8.000000
# 25%            41.000000
# 50%            55.500000
# 75%            71.000000
# max           153.000000

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Distance_km                0
# Weather                   30
# Traffic_Level             30
# Time_of_Day               30
# Vehicle_Type               0
# Preparation_Time_min       0
# Courier_Experience_yrs    30
# Delivery_Time_min          0
# dtype: int64

# %%
df['Weather']=df['Weather'].fillna(df['Weather'].mode()[0])

# %%
df['Traffic_Level']=df['Traffic_Level'].fillna(df['Traffic_Level'].mode()[0])

# %%
df['Time_of_Day']=df['Time_of_Day'].fillna(df['Time_of_Day'].mode()[0])

# %%
df['Courier_Experience_yrs'] = df['Courier_Experience_yrs'].fillna(df['Courier_Experience_yrs'].median())

# %%
df.isnull().sum()
# Out:
# Order_ID                  0
# Distance_km               0
# Weather                   0
# Traffic_Level             0
# Time_of_Day               0
# Vehicle_Type              0
# Preparation_Time_min      0
# Courier_Experience_yrs    0
# Delivery_Time_min         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   int64
#  1   Distance_km             1000 non-null   float64
#  2   Weather                 1000 non-null   str
#  3   Traffic_Level           1000 non-null   str
#  4   Time_of_Day             1000 non-null   str
#  5   Vehicle_Type            1000 non-null   str
#  6   Preparation_Time_min    1000 non-null   int64
#  7   Courier_Experience_yrs  1000 non-null   float64
#  8   Delivery_Time_min       1000 non-null   int64
# dtypes: float64(2), int64(3), str(4)
# memory usage: 91.5 KB

# %%
categorical_clm = ['Weather', 'Traffic_Level','Time_of_Day', 'Vehicle_Type' ]

# %%
for clm in categorical_clm:
    sns.boxplot(x = clm, y = 'Delivery_Time_min',data = df)
    plt.show()

# %%
numeric_clm = [ 'Distance_km', 'Preparation_Time_min', 'Courier_Experience_yrs']

# %%
for clm in numeric_clm:
    sns.scatterplot( x = clm, y = 'Delivery_Time_min',data= df)
    plt.show()

# %%
df.drop(columns= ['Order_ID'], inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Distance_km             1000 non-null   float64
#  1   Weather                 1000 non-null   str
#  2   Traffic_Level           1000 non-null   str
#  3   Time_of_Day             1000 non-null   str
#  4   Vehicle_Type            1000 non-null   str
#  5   Preparation_Time_min    1000 non-null   int64
#  6   Courier_Experience_yrs  1000 non-null   float64
#  7   Delivery_Time_min       1000 non-null   int64
# dtypes: float64(2), int64(2), str(4)
# memory usage: 83.7 KB

# %% [markdown]
# Feature Engineering

# %%
for clm in categorical_clm:
    print(df[clm].value_counts())
# Out:
# Weather
# Clear    500
# Rainy    204
# Foggy    103
# Snowy     97
# Windy     96
# Name: count, dtype: int64
# Traffic_Level
# Medium    420
# Low       383
# High      197
# Name: count, dtype: int64
# Time_of_Day
# Morning      338
# Evening      293
# Afternoon    284
# Night         85
# Name: count, dtype: int64
# Vehicle_Type
# Bike       503
# Scooter    302
# Car        195
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1000, 8)

# %%
X = df.drop(columns=['Delivery_Time_min'])
y = df['Delivery_Time_min']

# %%
print(y.shape)
print(X.shape)
# Out:
# (1000,)
# (1000, 7)

# %% [markdown]
# One hot encoding

# %%
df = pd.get_dummies(
    df,
    columns=['Weather', 'Time_of_Day', 'Vehicle_Type'],
    dtype=int
)

# %%
df['Traffic_Level'] = df['Traffic_Level'].map({
    'Low': 0,
    'Medium': 1,
    'High': 2
})

# %%
df
# Out:
#      Distance_km  Traffic_Level  Preparation_Time_min  Courier_Experience_yrs  \
# 0           7.93              0                    12                     1.0
# 1          16.42              1                    20                     2.0
# 2           9.52              0                    28                     1.0
# 3           7.44              1                     5                     1.0
# 4          19.03              0                    16                     5.0
# ..           ...            ...                   ...                     ...
# 995         8.50              2                    13                     3.0
# 996        16.28              0                     8                     9.0
# 997        15.62              2                    26                     2.0
# 998        14.17              0                     8                     0.0
# 999         6.63              0                    24                     3.0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['Delivery_Time_min'])
y = df['Delivery_Time_min']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    random_state= 42,
    test_size= 0.2
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
model_linear = LinearRegression()
model_linear.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred_linier = model_linear.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error

# %%
mae = mean_absolute_error(y_test,  y_pred_linier)
mae
# Out:
# 5.899582676018095

# %%
r2 = r2_score(y_test,  y_pred_linier)
r2
# Out:
# 0.826369033299585

# %%
rmse = root_mean_squared_error(y_test,  y_pred_linier)
rmse
# Out:
# 8.821909258797257

# %%
from sklearn.linear_model import Lasso

# %%
model_lasso = Lasso()
model_lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso()

# %%
y_pred_lasso = model_lasso.predict(X_test_scaled)

# %%
mae = mean_absolute_error(y_test, y_pred_lasso)
rmse = root_mean_squared_error(y_test, y_pred_lasso)
r2 = r2_score(y_test, y_pred_lasso)

print("MAE :", mae)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# MAE : 6.571582893002164
# RMSE: 9.3581047520601
# R²  : 0.8046210303372976

# %%
from sklearn.linear_model import Ridge

# %%
model_ridge = Ridge()
model_ridge.fit(X_train_scaled, y_train)
# Out:
# Ridge()

# %%
y_pred_ridge = model_ridge.predict(X_test_scaled)

# %%
mae = mean_absolute_error(y_test, y_pred_ridge)
rmse = root_mean_squared_error(y_test, y_pred_ridge)
r2 = r2_score(y_test, y_pred_ridge)

print("MAE :", mae)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# MAE : 5.903172005117318
# RMSE: 8.822194126806243
# R²  : 0.8263578196937956

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_DT = DecisionTreeRegressor()
model_DT.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_DT = model_DT.predict(X_test_scaled)

# %%
mae = mean_absolute_error(y_test, y_pred_DT)
rmse = root_mean_squared_error(y_test, y_pred_DT)
r2 = r2_score(y_test, y_pred_DT)

print("MAE :", mae)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# MAE : 10.915
# RMSE: 15.594069385506787
# R²  : 0.45747352666581487
